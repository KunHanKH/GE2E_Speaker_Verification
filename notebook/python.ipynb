# %%
import random
import sys
import os
if os.path.join('..') not in sys.path:
    sys.path.append(os.path.join('..'))
from utils.parse_config import config_param

# %%
train_config = config_param.train.TI_SV_train
data_config = config_param.data.TI_SV_data
path = data_config.train_path_processed
speaker_paths = list([os.path.join(path, speaker) for speaker in os.listdir(path)])

# %%
speaker_paths
# Out:
# ['../dataset/processed/tisv/train\\speaker0.npy',
#  '../dataset/processed/tisv/train\\speaker1.npy',
#  '../dataset/processed/tisv/train\\speaker10.npy',
#  '../dataset/processed/tisv/train\\speaker100.npy',
#  '../dataset/processed/tisv/train\\speaker101.npy',
#  '../dataset/processed/tisv/train\\speaker102.npy',
#  '../dataset/processed/tisv/train\\speaker103.npy',
#  '../dataset/processed/tisv/train\\speaker104.npy',
#  '../dataset/processed/tisv/train\\speaker105.npy',
#  '../dataset/processed/tisv/train\\speaker106.npy',
#  '../dataset/processed/tisv/train\\speaker107.npy',
#  '../dataset/processed/tisv/train\\speaker108.npy',
#  '../dataset/processed/tisv/train\\speaker109.npy',
#  '../dataset/processed/tisv/train\\speaker11.npy',
#  '../dataset/processed/tisv/train\\speaker110.npy',
#  '../dataset/processed/tisv/train\\speaker111.npy',
#  '../dataset/processed/tisv/train\\speaker112.npy',
#  '../dataset/processed/tisv/train\\speaker113.npy',
# ...

# %%
speaker_paths = random.shuffle(speaker_paths)

# %%
perm = random.sample(speaker_paths, len(speaker_paths))

# %%
perm
# Out:
# ['../dataset/processed/tisv/train\\speaker482.npy',
#  '../dataset/processed/tisv/train\\speaker374.npy',
#  '../dataset/processed/tisv/train\\speaker409.npy',
#  '../dataset/processed/tisv/train\\speaker386.npy',
#  '../dataset/processed/tisv/train\\speaker11.npy',
#  '../dataset/processed/tisv/train\\speaker533.npy',
#  '../dataset/processed/tisv/train\\speaker249.npy',
#  '../dataset/processed/tisv/train\\speaker62.npy',
#  '../dataset/processed/tisv/train\\speaker430.npy',
#  '../dataset/processed/tisv/train\\speaker201.npy',
#  '../dataset/processed/tisv/train\\speaker52.npy',
#  '../dataset/processed/tisv/train\\speaker248.npy',
#  '../dataset/processed/tisv/train\\speaker76.npy',
#  '../dataset/processed/tisv/train\\speaker239.npy',
#  '../dataset/processed/tisv/train\\speaker338.npy',
#  '../dataset/processed/tisv/train\\speaker188.npy',
#  '../dataset/processed/tisv/train\\speaker323.npy',
#  '../dataset/processed/tisv/train\\speaker541.npy',
# ...

# %%
random.sample(list(range(5)), 5)
# Out:
# [1, 3, 2, 0, 4]

# %%
>>> x = ['foo','bar','black','sheep']
>>> from random import shuffle
>>> print(shuffle(x))
# Out:
# None
